# %%
import sys
import os
sys.path.append('../src') # Needed for right import from FairModels

from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
from fairlearn.reductions import ExponentiatedGradient, DemographicParity
from fairlearn.metrics import demographic_parity_difference
from sklearn.tree import DecisionTreeClassifier
import argparse
import random
import tensorflow as tf
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
import optuna

from load_data import DATALOADER

# Import models
from src.FairModels.ICVAE import ICVAE
from src.FairModels.BinaryMI import BinaryMI
from src.FairModels.VFAE import VFAE
# Out:
# 2025-10-28 11:34:57.461565: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/torch/_functorch/deprecated.py:61: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')

# %%
MODELS = {
    "BinaryMI": BinaryMI,
    "VFAE": VFAE,
    "ICVAE": ICVAE
}


HYPERPARAMS = {
    "BinaryMI": [('num_hidden_layers',"int",(2,5)),('size_hidden_layers',"int",(5,30)),("kernel_regularizer","categorical",[0,0.01,0.001]),
                 ("drop_out","categorical",[0.0,0.2,0.5]),("set_quantized_position","fixed",True),("run_eagerly","fixed",False),
                 ("batch_size","fixed",256),("epoch","int",(10,50))],
    "VFAE": [('num_hidden_layers',"int",(2,5)),("size_hidden_layers","int",(5,30)),("kernel_regularizer","categorical",[0,0.01,0.001]),
                 ("drop_out","categorical",[0.0,0.2,0.5]),("batch_size","fixed",256),("epoch","int",(10,50)),("dim_z","int",(5,30))],
    "ICVAE": [('num_hidden_layers',"int",(2,5)),('size_hidden_layers',"int",(5,30)),("kernel_regularizer","categorical",[0,0.01,0.001]),
                ("drop_out","categorical",[0.0,0.2,0.5]),("batch_size","fixed",256),("epoch","int",(10,50)),("dim_z","int",(5,30))]
}

# %%
def _hp_optimization(model, hps, X, y, S,n_trials, n_folds, random_seed, stratified=True):
    X = X.to_numpy()
    fixed_params = {}
    for hp in hps:
        if hp[1] == "fixed":
            fixed_params[hp[0]] = hp[2]
    
    def objective(trial):
        hp_trial_dict = {}
        
        for hp in hps:
            if hp[1] == "categorical":
                hp_trial_dict[hp[0]] = trial.suggest_categorical(hp[0], hp[2])
            elif hp[1] == "int":
                hp_trial_dict[hp[0]] = trial.suggest_int(hp[0], hp[2][0], hp[2][1])
            elif hp[1] == "float":
                hp_trial_dict[hp[0]] = trial.suggest_float(hp[0], hp[2][0], hp[2][1])
        
        cur_model = model(**hp_trial_dict,**fixed_params)
        
        if stratified:
            kf = StratifiedKFold(n_splits=n_folds, random_state=random_seed, shuffle=True)
        else:
            kf = KFold(n_splits=n_folds, random_state=random_seed, shuffle=True)
        auc = []
        for i, (train_index, test_index) in enumerate(kf.split(X, y)):
            cur_model.fit(X[train_index], y[train_index], S[train_index])
            y_pred = cur_model.predict_proba(X[test_index])
            y_pred = [1 if x > 0.5 else 0 for x in y_pred]
            cur_acc = roc_auc_score(y[test_index], y_pred)
            auc.append(cur_acc)
        return np.mean(auc)
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=n_trials)
    return study.best_value ,{**study.best_params, **fixed_params}

# %%
def test_loop(model,X_train,X_test,y_train,y_test,S_train,S_test,gammas,path,hps={}, do_hp_opt=True):
    accuracies = pd.DataFrame(columns=["gamma","acc","dp","acc_threshold","dp_threshold","optimal_threshold"])
    accuracies.set_index("gamma", inplace=True)
    hps.append(("",""))

    for gamma in gammas: 
        hps = hps[:-1] # Delete previous gamma value
        hps.append(("gamma","fixed",gamma)) # Set new gamma
        print(f"Gamma: {gamma}")
        
        _, best_hps = _hp_optimization(model, hps, X_train, y_train, S_train, 50, 3, SEED) # HP-Opt. with 50 combinations and 3-fold cv
        cur_model = model(**best_hps)
        cur_model.fit(X_train, y_train, S_train)

        # Get optimal threshold
        X_val, X_test_holdout, y_val, y_test_holdout, s_val, s_test_holdout = train_test_split(X_test, y_test, S_test, test_size=0.66, random_state=SEED)
        t = np.zeros(5)
        for i in range(5):
            y_prob = cur_model.predict_proba(X_val)
            fpr, tpr, thresholds = roc_curve(y_val, y_prob)
            youden_j = tpr - fpr
            optimal_idx = np.argmax(youden_j) 
            t[i] = thresholds[optimal_idx]
        t = t[~np.isinf(t)]
        optimal_threshold = t.mean()

        # Evaluate model and save results
        y_prob = cur_model.predict_proba(X_test)
        y_pred = [1 if x > 0.5 else 0 for x in y_prob]
        acc = accuracy_score(y_test, y_pred)
        dp = demographic_parity_difference(y_test, y_pred, sensitive_features=S_test)

        y_pred = [1 if x > optimal_threshold else 0 for x in y_prob]
        acc_threshold = accuracy_score(y_test, y_pred)
        dp_threshold = demographic_parity_difference(y_test, y_pred, sensitive_features=S_test)

        accuracies.loc[gamma] = acc, dp, acc_threshold, dp_threshold ,optimal_threshold
        accuracies.to_csv(f"{path}/accuracies.csv")

# %%
SEED = 123
random.seed(SEED)
tf.random.set_seed(SEED)
np.random.seed(SEED)

dataset = "adult"
model_name = "BinaryMI"
path = f"{dataset}_{model_name}_{datetime.now().strftime('%d-%m-%Y_%H-%M-%S')}"
os.makedirs(path, exist_ok=True)

X_train, X_test, y_train, y_test, S_train, S_test = DATALOADER[dataset](SEED)

model = MODELS[model_name]
hps = HYPERPARAMS[model_name]

gammas = np.linspace(0,1,11)
test_loop(model,X_train,X_test,y_train,y_test,S_train,S_test,gammas,path,hps)
# Out:
# [I 2025-10-28 11:35:21,184] A new study created in memory with name: no-name-6f35d394-1340-4b26-badd-568805919bc5
# Gamma: 0.0
# [I 2025-10-28 11:36:01,705] Trial 0 finished with value: 0.5001327108343953 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 17, 'kernel_regularizer': 0.001, 'drop_out': 0.2, 'epoch': 43}. Best is trial 0 with value: 0.5001327108343953.
# [I 2025-10-28 11:36:30,134] Trial 1 finished with value: 0.5000303692905733 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 28, 'kernel_regularizer': 0.01, 'drop_out': 0.2, 'epoch': 34}. Best is trial 0 with value: 0.5001327108343953.
# [I 2025-10-28 11:36:58,821] Trial 2 finished with value: 0.5 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 30, 'kernel_regularizer': 0.01, 'drop_out': 0.0, 'epoch': 44}. Best is trial 0 with value: 0.5001327108343953.
# [I 2025-10-28 11:37:40,698] Trial 3 finished with value: 0.5 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.5, 'epoch': 47}. Best is trial 0 with value: 0.5001327108343953.
# [I 2025-10-28 11:38:18,126] Trial 4 finished with value: 0.5165301860117735 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 26, 'kernel_regularizer': 0.001, 'drop_out': 0.2, 'epoch': 46}. Best is trial 4 with value: 0.5165301860117735.
# [I 2025-10-28 11:38:39,165] Trial 5 finished with value: 0.5 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 25, 'kernel_regularizer': 0, 'drop_out': 0.5, 'epoch': 16}. Best is trial 4 with value: 0.5165301860117735.
# [I 2025-10-28 11:39:12,483] Trial 6 finished with value: 0.4951589510627527 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 18, 'kernel_regularizer': 0.01, 'drop_out': 0.5, 'epoch': 42}. Best is trial 4 with value: 0.5165301860117735.
# [I 2025-10-28 11:39:39,441] Trial 7 finished with value: 0.5161448035700323 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 6, 'kernel_regularizer': 0.001, 'drop_out': 0.5, 'epoch': 32}. Best is trial 4 with value: 0.5165301860117735.
# [I 2025-10-28 11:40:12,212] Trial 8 finished with value: 0.5313231634299095 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 9, 'kernel_regularizer': 0.001, 'drop_out': 0.5, 'epoch': 39}. Best is trial 8 with value: 0.5313231634299095.
# [I 2025-10-28 11:40:40,709] Trial 9 finished with value: 0.574620626373837 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 29, 'kernel_regularizer': 0.001, 'drop_out': 0.2, 'epoch': 43}. Best is trial 9 with value: 0.574620626373837.
# [I 2025-10-28 11:41:01,545] Trial 10 finished with value: 0.5968667630765477 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 19, 'kernel_regularizer': 0.001, 'drop_out': 0.0, 'epoch': 18}. Best is trial 10 with value: 0.5968667630765477.
# [I 2025-10-28 11:41:28,580] Trial 11 finished with value: 0.5818273254127916 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 20, 'kernel_regularizer': 0.001, 'drop_out': 0.0, 'epoch': 22}. Best is trial 10 with value: 0.5968667630765477.
# [I 2025-10-28 11:41:50,789] Trial 12 finished with value: 0.5627851033317864 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 19, 'kernel_regularizer': 0.001, 'drop_out': 0.0, 'epoch': 17}. Best is trial 10 with value: 0.5968667630765477.
# [I 2025-10-28 11:42:16,316] Trial 13 finished with value: 0.5957353218099067 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 22, 'kernel_regularizer': 0.001, 'drop_out': 0.0, 'epoch': 23}. Best is trial 10 with value: 0.5968667630765477.
# [I 2025-10-28 11:42:37,598] Trial 14 finished with value: 0.5596860795042881 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 13, 'kernel_regularizer': 0.001, 'drop_out': 0.0, 'epoch': 24}. Best is trial 10 with value: 0.5968667630765477.
# [I 2025-10-28 11:42:50,161] Trial 15 finished with value: 0.6353250215724681 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 23, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 15 with value: 0.6353250215724681.
# [I 2025-10-28 11:43:02,824] Trial 16 finished with value: 0.6356053113154578 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 22, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 16 with value: 0.6356053113154578.
# [I 2025-10-28 11:43:17,601] Trial 17 finished with value: 0.6513561904980691 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 24, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 17 with value: 0.6513561904980691.
# [I 2025-10-28 11:43:32,218] Trial 18 finished with value: 0.6125927342158318 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 15, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 17 with value: 0.6513561904980691.
# [I 2025-10-28 11:43:48,094] Trial 19 finished with value: 0.6857072089499838 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 24, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 12}. Best is trial 19 with value: 0.6857072089499838.
# [I 2025-10-28 11:44:10,668] Trial 20 finished with value: 0.7526583609641406 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 24, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 27}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:44:32,853] Trial 21 finished with value: 0.7435710490550456 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 24, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 27}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:44:54,701] Trial 22 finished with value: 0.7034831844961204 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 21, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 27}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:45:16,961] Trial 23 finished with value: 0.7347957779524608 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 22, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 27}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:45:43,141] Trial 24 finished with value: 0.7290523560931396 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 26, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 31}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:46:08,423] Trial 25 finished with value: 0.7083309705890128 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 16, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 36}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:46:30,072] Trial 26 finished with value: 0.6774963961061403 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 13, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 27}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:46:51,405] Trial 27 finished with value: 0.6532613777778112 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 21, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 28}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:47:15,094] Trial 28 finished with value: 0.6065567369124776 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 24, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 20}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:47:38,684] Trial 29 finished with value: 0.5 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 28, 'kernel_regularizer': 0.01, 'drop_out': 0.0, 'epoch': 25}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:48:06,138] Trial 30 finished with value: 0.5857399352505479 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 17, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 30}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:48:31,528] Trial 31 finished with value: 0.7174014671578371 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 26, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 31}. Best is trial 20 with value: 0.7526583609641406.
# [I 2025-10-28 11:49:00,437] Trial 32 finished with value: 0.7584851335907613 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 26, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 36}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:49:29,039] Trial 33 finished with value: 0.6899946239175744 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 30, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 35}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:50:02,489] Trial 34 finished with value: 0.5 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 28, 'kernel_regularizer': 0.01, 'drop_out': 0.0, 'epoch': 50}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:50:28,286] Trial 35 finished with value: 0.7226833996699836 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 23, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 38}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:50:59,450] Trial 36 finished with value: 0.5961211728626715 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 34}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:51:26,155] Trial 37 finished with value: 0.4999649531405337 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 25, 'kernel_regularizer': 0.01, 'drop_out': 0.5, 'epoch': 29}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:51:47,025] Trial 38 finished with value: 0.701238840729823 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 22, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 26}. Best is trial 32 with value: 0.7584851335907613.
# [I 2025-10-28 11:52:14,806] Trial 39 finished with value: 0.7657732146372327 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 33}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:52:49,413] Trial 40 finished with value: 0.5383681428236319 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 30, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 38}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:53:16,477] Trial 41 finished with value: 0.7444899878941004 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 33}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:53:47,890] Trial 42 finished with value: 0.5 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.5, 'epoch': 33}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:54:20,006] Trial 43 finished with value: 0.7404841220967135 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 28, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 40}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:54:47,334] Trial 44 finished with value: 0.7210593511749229 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 25, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 33}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:55:16,538] Trial 45 finished with value: 0.5 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 29, 'kernel_regularizer': 0.01, 'drop_out': 0.0, 'epoch': 36}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:55:52,406] Trial 46 finished with value: 0.5005743825387708 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.5, 'epoch': 41}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:56:14,328] Trial 47 finished with value: 0.7538209444528525 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 29, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 21}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:56:35,258] Trial 48 finished with value: 0.7581859653117294 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 29, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 19}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:56:57,519] Trial 49 finished with value: 0.746986125394003 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 30, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 22}. Best is trial 39 with value: 0.7657732146372327.
# [I 2025-10-28 11:57:08,842] A new study created in memory with name: no-name-607908cd-c06a-44e8-a44a-1be857aeb5f9
# Gamma: 0.1
# [I 2025-10-28 11:57:29,212] Trial 0 finished with value: 0.49998221543771626 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 9, 'kernel_regularizer': 0.01, 'drop_out': 0.5, 'epoch': 25}. Best is trial 0 with value: 0.49998221543771626.
# [I 2025-10-28 11:57:52,274] Trial 1 finished with value: 0.5353148497538581 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 12, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 17}. Best is trial 1 with value: 0.5353148497538581.
# [I 2025-10-28 11:58:22,188] Trial 2 finished with value: 0.571083847589621 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 14, 'kernel_regularizer': 0.001, 'drop_out': 0.5, 'epoch': 45}. Best is trial 2 with value: 0.571083847589621.
# [I 2025-10-28 11:58:42,622] Trial 3 finished with value: 0.5566516321284863 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 24, 'kernel_regularizer': 0.001, 'drop_out': 0.5, 'epoch': 25}. Best is trial 2 with value: 0.571083847589621.
# [I 2025-10-28 11:59:06,483] Trial 4 finished with value: 0.5113690572591374 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 13, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 22}. Best is trial 2 with value: 0.571083847589621.
# [I 2025-10-28 11:59:32,492] Trial 5 finished with value: 0.5277371631649145 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 17, 'kernel_regularizer': 0.001, 'drop_out': 0.0, 'epoch': 33}. Best is trial 2 with value: 0.571083847589621.
# [I 2025-10-28 11:59:52,121] Trial 6 finished with value: 0.5128127687856753 and parameters: {'num_hidden_layers': 2, 'size_hidden_layers': 5, 'kernel_regularizer': 0.01, 'drop_out': 0.2, 'epoch': 24}. Best is trial 2 with value: 0.571083847589621.
# [I 2025-10-28 12:00:17,144] Trial 7 finished with value: 0.5 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 15, 'kernel_regularizer': 0.01, 'drop_out': 0.5, 'epoch': 31}. Best is trial 2 with value: 0.571083847589621.
# [I 2025-10-28 12:00:38,738] Trial 8 finished with value: 0.5963321519234789 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 28, 'kernel_regularizer': 0, 'drop_out': 0.2, 'epoch': 17}. Best is trial 8 with value: 0.5963321519234789.
# [I 2025-10-28 12:00:58,655] Trial 9 finished with value: 0.5094492685314752 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 21, 'kernel_regularizer': 0.001, 'drop_out': 0.5, 'epoch': 17}. Best is trial 8 with value: 0.5963321519234789.
# [I 2025-10-28 12:01:16,859] Trial 10 finished with value: 0.6792411794685552 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 30, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 13}. Best is trial 10 with value: 0.6792411794685552.
# [I 2025-10-28 12:01:33,692] Trial 11 finished with value: 0.7118378160922108 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 30, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 11 with value: 0.7118378160922108.
# [I 2025-10-28 12:01:50,189] Trial 12 finished with value: 0.6114264407361313 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 29, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 13}. Best is trial 11 with value: 0.7118378160922108.
# [I 2025-10-28 12:02:06,442] Trial 13 finished with value: 0.6880096917613829 and parameters: {'num_hidden_layers': 5, 'size_hidden_layers': 23, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 11 with value: 0.7118378160922108.
# [I 2025-10-28 12:02:23,057] Trial 14 finished with value: 0.6920150095493351 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 24, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 10}. Best is trial 11 with value: 0.7118378160922108.
# [I 2025-10-28 12:02:55,075] Trial 15 finished with value: 0.7216168608296253 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 25, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 38}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:03:26,121] Trial 16 finished with value: 0.7101214996665298 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 27, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 39}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:04:04,650] Trial 17 finished with value: 0.691352447697091 and parameters: {'num_hidden_layers': 4, 'size_hidden_layers': 21, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 50}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:04:35,307] Trial 18 finished with value: 0.7129137354938863 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 26, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 37}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:05:05,885] Trial 19 finished with value: 0.5 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 26, 'kernel_regularizer': 0.01, 'drop_out': 0.0, 'epoch': 37}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:05:37,690] Trial 20 finished with value: 0.6944291276890245 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 19, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 41}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:06:08,934] Trial 21 finished with value: 0.71235930697872 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 26, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 37}. Best is trial 15 with value: 0.7216168608296253.
# [I 2025-10-28 12:06:37,764] Trial 22 finished with value: 0.6983429122623566 and parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 26, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 34}. Best is trial 15 with value: 0.7216168608296253.
# [W 2025-10-28 12:06:57,709] Trial 23 failed with parameters: {'num_hidden_layers': 3, 'size_hidden_layers': 21, 'kernel_regularizer': 0, 'drop_out': 0.0, 'epoch': 43} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/lz/xk74mjz162n7c2k2y1p9ts8c0000gn/T/ipykernel_4110/2090551508.py", line 27, in objective
#     cur_model.fit(X[train_index], y[train_index], S[train_index])
#   File "/Users/philippwolf/combined_project/randomness_experiments/src/FairModels/BinaryMI.py", line 327, in fit
#     self.history = self.model.fit( # type: ignore
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#     return fn(*args, **kwargs)
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 325, in fit
#     logs = self.train_function(iterator)
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py", line 833, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py", line 878, in _call
#     results = tracing_compilation.call_function(
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py", line 138, in call_function
#     flat_inputs = function.function_type.unpack_inputs(bound_args)
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/core/function/polymorphism/function_type.py", line 391, in unpack_inputs
#     p.type_constraint.to_tensors(bound_parameters.arguments[p.name])
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py", line 253, in to_tensors
#     self._component_specs,
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 948, in _component_specs
#     return (tensor.TensorSpec([], dtypes.resource),)
#   File "/Users/philippwolf/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/framework/tensor.py", line 853, in __init__
#     def __init__(self, shape, dtype=dtypes.float32, name=None):
# KeyboardInterrupt
# [W 2025-10-28 12:06:58,124] Trial 23 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 17
#      14 hps = HYPERPARAMS[model_name]
#      16 gammas = np.linspace(0,1,11)
# ---> 17 test_loop(model,X_train,X_test,y_train,y_test,S_train,S_test,gammas,path,hps)
#
# Cell In[4], line 11, in test_loop(model, X_train, X_test, y_train, y_test, S_train, S_test, gammas, path, hps, do_hp_opt)
#       8 hps.append(("gamma","fixed",gamma)) # Set new gamma
#       9 print(f"Gamma: {gamma}")
# ---> 11 _, best_hps = _hp_optimization(model, hps, X_train, y_train, S_train, 50, 3, SEED) # HP-Opt. with 50 combinations and 3-fold cv
#      12 cur_model = model(**best_hps)
#      13 cur_model.fit(X_train, y_train, S_train)
#
# Cell In[3], line 34, in _hp_optimization(model, hps, X, y, S, n_trials, n_folds, random_seed, stratified)
#      32     return np.mean(auc)
#      33 study = optuna.create_study(direction='maximize')
# ---> 34 study.optimize(objective, n_trials=n_trials)
#      35 return study.best_value ,{**study.best_params, **fixed_params}
#
# File ~/combined_project/venv/lib/python3.9/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/combined_project/venv/lib/python3.9/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File ~/combined_project/venv/lib/python3.9/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File ~/combined_project/venv/lib/python3.9/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File ~/combined_project/venv/lib/python3.9/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[3], line 27, in _hp_optimization.<locals>.objective(trial)
#      25 auc = []
#      26 for i, (train_index, test_index) in enumerate(kf.split(X, y)):
# ---> 27     cur_model.fit(X[train_index], y[train_index], S[train_index])
#      28     y_pred = cur_model.predict_proba(X[test_index])
#      29     y_pred = [1 if x > 0.5 else 0 for x in y_pred]
#
# File ~/combined_project/randomness_experiments/src/FairModels/BinaryMI.py:327, in BinaryMI.fit(self, x, y, s, **fit_params)
#     323 y = tf.keras.utils.to_categorical(y, self.last_layer_size)
#     325 self._build_model()
# --> 327 self.history = self.model.fit( # type: ignore
#     328     x=x,
#     329     y=[y, s],
#     330     batch_size=self.batch_size,
#     331     epochs=self.epoch,
#     332     verbose=self.verbose,
#     333     shuffle=True,
#     334     validation_split=self.validation_size
#     335 ).history
#     336 # https://github.com/tensorflow/tensorflow/issues/14181
#     337 # https://github.com/tensorflow/tensorflow/issues/30324
#     338 gc.collect()
#
# File ~/combined_project/venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/combined_project/venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:325, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     323 for step, iterator in epoch_iterator.enumerate_epoch():
#     324     callbacks.on_train_batch_begin(step)
# --> 325     logs = self.train_function(iterator)
#     326     callbacks.on_train_batch_end(
#     327         step, self._pythonify_logs(logs)
#     328     )
#     329     if self.stop_training:
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:138, in call_function(args, kwargs, tracing_options)
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
# --> 138 flat_inputs = function.function_type.unpack_inputs(bound_args)
#     139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/core/function/polymorphism/function_type.py:391, in FunctionType.unpack_inputs(self, bound_parameters)
#     388 flat = []
#     389 for p in sorted_parameters:
#     390   flat.extend(
# --> 391       p.type_constraint.to_tensors(bound_parameters.arguments[p.name])
#     392   )
#     394 dealiased_inputs = []
#     395 ids_used = set()
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py:253, in TypeSpec.to_tensors(self, value)
#     248 """See TraceType base class for details. Do not override."""
#     250 tensors = []
#     251 nest.map_structure(
#     252     lambda spec, v: tensors.extend(spec.to_tensors(v)),
# --> 253     self._component_specs,
#     254     self._to_components(value))
#     255 return tensors
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:948, in IteratorSpec._component_specs(self)
#     946 @property
#     947 def _component_specs(self):
# --> 948   return (tensor.TensorSpec([], dtypes.resource),)
#
# File ~/combined_project/venv/lib/python3.9/site-packages/tensorflow/python/framework/tensor.py:853, in DenseSpec.__init__(self, shape, dtype, name)
#     849 __slots__ = ["_shape", "_dtype", "_name"]
#     851 _component_specs = property(lambda self: self)
# --> 853 def __init__(self, shape, dtype=dtypes.float32, name=None):
#     854   """Creates a TensorSpec.
#     855
#     856   Args:
#    (...)
#     863       not convertible to a `tf.DType`.
#     864   """
#     865   self._shape = tensor_shape.TensorShape(shape)
#
# KeyboardInterrupt:
